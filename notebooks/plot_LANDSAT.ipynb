# %%
from rs_fns import stack_landsat, normalize
from glob import glob
import matplotlib.pyplot as plt
import numpy as np

# %%
image1_bands = glob("landsat_20190125/*")
image1_bands.sort()

bands = [image1_bands[2], image1_bands[1], image1_bands[0]]

X,Y,rgb = stack_landsat(bands)
# Out:
# ['landsat_20190125/LC08_L1GT_167109_20190125_20190205_01_T2_B2.TIF', 'landsat_20190125/LC08_L1GT_167109_20190125_20190205_01_T2_B3.TIF', 'landsat_20190125/LC08_L1GT_167109_20190125_20190205_01_T2_B4.TIF']

# %%
# %matplotlib inline
plt.figure()
plt.imshow(rgb, extent = [np.min(X), np.max(X), np.min(Y), np.max(Y)])
